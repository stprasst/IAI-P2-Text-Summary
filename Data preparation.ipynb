# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Converting JSON to CSV with Random Sampling

# %% [markdown]
# ### Dependencies & Load .JSON files

# %%
import json
import random
import csv
import os
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
#load json
def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# %% [markdown]
# ### Random Sampling for Train file and setting total datasets to 10k

# %%
def random_sampling_from_files(directory, sample_size):
    sampled_data = []
    all_files = [f for f in os.listdir(directory) if f.endswith('.json')]
    total_files = len(all_files)
    
    if sample_size > total_files:
        print(f"Warning: Sample size ({sample_size}) is larger than the number of files ({total_files}). Using all files.")
        files_to_sample = all_files
    else:
        files_to_sample = random.sample(all_files, sample_size)
    
    for file_name in tqdm(files_to_sample, desc="Sampling files"):
        file_path = os.path.join(directory, file_name)
        
        try:
            data = load_json(file_path)
            if isinstance(data, list) and len(data) > 0:
                sampled_data.append(random.choice(data))
            elif isinstance(data, dict):
                sampled_data.append(data)
        except FileNotFoundError:
            print(f"File {file_name} not found. Skipping.")
        except json.JSONDecodeError:
            print(f"Error decoding {file_name}. Skipping.")
        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}. Skipping.")
    
    return sampled_data

def main():
    directory = r'F:\\AI Portfolio Project\\Project 2\\liputan6_data\\canonical\\train'  # Directory file train (wajib double string biar ga error)
    sample_size = 10000 #fixed 10k only

    global sampled_data
    sampled_data = random_sampling_from_files(directory, sample_size)
    
    print(f"Random sampling complete.")

if __name__ == "__main__":
    main()
# Out:
# Sampling files: 100%|██████████| 10000/10000 [02:33<00:00, 65.31it/s]
# Random sampling complete.

# %%
sampled_data_train = sampled_data
sampled_data_train[0]
# Out:
# {'id': 288252,
#  'url': 'https://www.liputan6.com/news/read/288252/pemerintah-akui-kemungkinan-kualitas-premium-kurang-baik',
#  'clean_article': [['Liputan6',
#    '.',
#    'com',
#    ',',
#    'Jakarta',
#    ':',
#    'Hingga',
#    'kini',
#    'kerusakan',
#    'fuel',
#    'pump',
#    'atau',
#    'pompa',
#    'bahan',
#    'bakar',
#    'pada',
#    'mobil',
#    'yang',
#    'menggunakan',
#    'premium',
#    'masih',
#    'saja',
#    'terjadi',
#    '.'],
#   ['Bengkel',
#    'umum',
#    'pun',
#    'masih',
#    'terus',
#    'kedatangan',
#    'mobil',
#    'yang',
#    'rusak',
#    '.'],
#   ['Menurut',
#    'sejumlah',
#    'mekanik',
#    'yang',
#    'ada',
#    'di',
#    'bengkel',
#    'di',
#    'berbagai',
#    'daerah',
#    ',',
#    'telah',
#    'terjadi',
#    'peningkatan',
#    'mobil',
#    'yang',
#    'mengalami',
#    'kerusakan',
#    'pompa',
#    'bahan',
#    'bakar',
#    '.'],
#   ['"',
#    'Kualitas',
#    'BBM',
#    'merupakan',
#    'salah',
#    'satu',
#    'faktor',
#    'penting',
#    'dalam',
#    'kerusakan',
#    'pompa',
#    'BBM',
#    ',',
#    'sehingga',
#    'mobilpun',
#    'akhirnya',
#    'mogok',
#    '"',
#    'kata',
#    'Yonri',
#    'Basrizal',
#    'mekanik',
#    'salah',
#    'bengkel',
#    '.'],
#   ['Pendapat',
#    'Yonri',
#    'dibenarkan',
#    'Udin',
#    'mekanik',
#    'dari',
#    'bengkel',
#    'lainnya',
#    '.'],
#   ['Meski',
#    'belum',
#    'ada',
#    'hasil',
#    'resmi',
#    'analisa',
#    'penyebab',
#    'keruskan',
#    'pompa',
#    'bahan',
#    'bakar',
#    ',',
#    'Menteri',
#    'ESDM',
#    'Darwin',
#    'Saleh',
#    'di',
#    'Jakarta',
#    ',',
#    'Selasa',
#    '(',
#    '27/7',
#    ')',
#    'menduga',
#    'tidak',
#    'tertutup',
#    'kemungkinan',
#    'kualitas',
#    'premium',
#    'yang',
#    'menjadi',
#    'penyebab',
#    'kerusakan',
#    'pada',
#    'pompa',
#    'bahan',
#    'bakar',
#    'yang',
#    'telah',
#    'membuat',
#    'mogok',
#    'lebih',
#    'dari',
#    'seribu',
#    'mobil',
#    'Sedangkan',
#    'Pertamina',
#    'yang',
#    'bertanggungjawab',
#    'dalam',
#    'pendistribusian',
#    'BBM',
#    'membantah',
#    'kalau',
#    'kualitas',
#    'premium',
#    'yang',
#    'dijualnya',
#    'kurang',
#    'baik',
#    '.'],
#   ['"',
#    'Menurut',
#    'hasil',
#    'tes',
#    'labolatorimum',
#    'terhadap',
#    'premium',
#    ',',
#    'masih',
#    'ada',
#    'dalam',
#    'batas',
#    'toleransi',
#    'yang',
#    'dizinkan',
#    ',',
#    '"',
#    'kata',
#    'Basuki',
#    'Trikora',
#    'Putra',
#    ',',
#    'HUmas',
#    'PT',
#    'Pertamina',
#    '.',
#    '(',
#    'AYB',
#    ')',
#    '.']],
#  'clean_summary': [['Meski',
#    'belum',
#    'ada',
#    'hasil',
#    'resmi',
#    'analisa',
#    'penyebab',
#    'keruskan',
#    'pompa',
#    'bahan',
#    'bakar',
#    ',',
#    'Menteri',
#    'ESDM',
#    'Darwin',
#    'Saleh',
#    'menduga',
#    'tidak',
#    'tertutup',
#    'kemungkinan',
#    'kualitas',
#    'premium',
#    'yang',
#    'menjadi',
#    'penyebab',
#    'kerusakan',
#    'pada',
#    'pompa',
#    'bahan',
#    'bakar',
#    'yang',
#    'telah',
#    'membuat',
#    'mogok',
#    'lebih',
#    'dari',
#    'seribu',
#    'mobil',
#    '.']],
#  'extractive_summary': [4, 5]}

# %%
#combining into "combined_clean_article" and "combined_clean_summary"
data_train = pd.json_normalize(sampled_data_train)

def normalize_text(tokenized_text):
    normalized_text = ""
    for sentence in tokenized_text:
        for word in sentence:
            if word in [".", ",", ":", ";", "!", "?", ")", "]"]:
                normalized_text = normalized_text.rstrip() + word + " "
            elif word in ["(", "["]:
                normalized_text += word
            else:
                normalized_text += word + " "
    return normalized_text.strip()


data_train['combined_clean_article'] = data_train['clean_article'].apply(normalize_text)
data_train['combined_clean_summary'] = data_train['clean_summary'].apply(normalize_text)

# %%
#checking1
data_train.head()
# Out:
#        id                                                url  \
# 0  288252  https://www.liputan6.com/news/read/288252/peme...
# 1  148249  https://www.liputan6.com/news/read/148249/fred...
# 2   30242  https://www.liputan6.com/news/read/30242/perke...
# 3  198447  https://www.liputan6.com/news/read/198447/pks-...
# 4   27679  https://www.liputan6.com/news/read/27679/pemda...
#
#                                        clean_article  \
# 0  [[Liputan6, ., com, ,, Jakarta, :, Hingga, kin...
# 1  [[Liputan6, ., com, ,, Jakarta, :, Freddy, San...
# 2  [[Liputan6, ., com, ,, Jakarta, :, Fotografi, ...
# 3  [[Liputan6, ., com, ,, Subang, :, Pro, kontra,...
# 4  [[Liputan6, ., com, ,, Jakarta, :, Pemda, Jaka...
#
#                                        clean_summary extractive_summary  \
# 0  [[Meski, belum, ada, hasil, resmi, analisa, pe...             [4, 5]
# 1  [[Freddy, Santoso, ,, pelaku, penyuapan, terha...             [0, 2]
# 2  [[Fotografi, mode, terus, berkembang, dengan, ...          [0, 2, 4]
# 3  [[Seniman, Subang, menyerukan, memboikot, PKS,...             [2, 6]
# 4  [[Suku, Dinas, Kependudukan, DKI, Jakarta, men...          [1, 9, 3]
#
#                               combined_clean_article  \
# 0  Liputan6. com, Jakarta: Hingga kini kerusakan ...
# 1  Liputan6. com, Jakarta: Freddy Santoso, pelaku...
# 2  Liputan6. com, Jakarta: Fotografi mode kini se...
# 3  Liputan6. com, Subang: Pro kontra tari jaipong...
# 4  Liputan6. com, Jakarta: Pemda Jakarta menggela...
#
#                               combined_clean_summary
# 0  Meski belum ada hasil resmi analisa penyebab k...
# 1  Freddy Santoso, pelaku penyuapan terhadap Iraw...
# 2  Fotografi mode terus berkembang dengan lebih m...
# 3  Seniman Subang menyerukan memboikot PKS dan me...
# 4  Suku Dinas Kependudukan DKI Jakarta menggelar ...

# %%
#checking2
data_train.sample(1)[["combined_clean_article", "combined_clean_summary"]].values
# Out:
# array([['Liputan6. com, Jakarta: Kepolisian RI membentuk tim khusus untuk membuktikan kebenaran dugaan adanya politik uang dalam pemilihan Gubernur DKI, beberapa waktu silam. Demikian diungkapkan Kepala Bagian Hubungan Masyarakat Polri Inspektur Jenderal Polisi Saleh Saaf, yang ditemui di ruang kerjanya, Selasa (17/9) [baca: Polisi Menyelidiki Kasus Suap Pemilihan Gubernur Jakarta]. Sayangnya, Saleh tak bersedia memberikan nama dan jumlah personel yang bekerja untuk kasus ini. Yang pasti, tambah Saleh, dalam waktu dekat ada seorang tokoh masyarakat yang namanya dirahasiakan akan datang ke Markas Besar Polri untuk memberikan keterangan seputar kasus tersebut. Ia juga mengaku hingga saat ini belum ditemukan adanya pengakuan, pengaduan, laporan atau bukti yang dapat dijadikan alasan dugaan adanya money politic dalam pemilihan tersebut. (PIN/Rubai Kadir dan Yosep HL).',
#         'Polri membentuk tim khusus untuk membuktikan kebenaran dugaan adanya politik uang dalam pemilihan Gubernur DKI. Seorang tokoh masyarakat akan memberikan keterangan seputar kasus tersebut.']],
#       dtype=object)

# %%
#save CSV
output_file = 'F:\\AI Portfolio Project\\Project 2-new\\datasets\\data_train.csv' # Directory untuk output (wajib double string biar ga error)
data_train.to_csv(output_file, index=False)
print(f"total {len(data_train)} items saved to {output_file}")
# Out:
# total 10000 items saved to F:\AI Portfolio Project\Project 2-new\datasets\data_train.csv

# %%
#before (focus on clean_article and clean_summary)
check_train = pd.read_csv('F:\AI Portfolio Project\Project 2-new\datasets\data_train.csv')
check_train.head()
# Out:
#   extractive_summary                                                url  \
# 0             [0, 2]  https://www.liputan6.com/news/read/269233/pasu...
# 1             [0, 2]  https://www.liputan6.com/news/read/55940/gembo...
# 2             [0, 1]  https://www.liputan6.com/news/read/201133/pela...
# 3             [4, 6]  https://www.liputan6.com/news/read/100076/kiai...
# 4             [0, 1]  https://www.liputan6.com/news/read/168844/adam...
#
#                                        clean_article  \
# 0  [['Liputan6', '.', 'com', ',', 'Parachinar', '...
# 1  [['Liputan6', '.', 'com', ',', 'Madura', ':', ...
# 2  [['Akhirnya', 'Federasi', 'Sepak', 'Bola', 'Ar...
# 3  [['Liputan6', '.', 'com', ',', 'Tuban', ':', '...
# 4  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
#
#                                        clean_summary      id
# 0  [['Sedikitnya', '14', 'orang', 'militan', 'tew...  269233
# 1  [['Polisi', 'menangkap', 'seorang', 'gembong',...   55940
# 2  [['Lantaran', 'prestasi', 'tim', 'Arab', 'Saud...  201133
# 3  [['Konflik', 'yang', 'terjadi', 'di', 'PKB', '...  100076
# 4  [['Mantan', 'Wapres', 'Adam', 'Malik', 'ditudi...  168844

# %%
#after (focus on clean_article and clean_summary)
check_train_after = pd.read_csv('F:\AI Portfolio Project\Project 2-new\datasets\data_train.csv')
check_train_after.head()
# Out:
#        id                                                url  \
# 0  288252  https://www.liputan6.com/news/read/288252/peme...
# 1  148249  https://www.liputan6.com/news/read/148249/fred...
# 2   30242  https://www.liputan6.com/news/read/30242/perke...
# 3  198447  https://www.liputan6.com/news/read/198447/pks-...
# 4   27679  https://www.liputan6.com/news/read/27679/pemda...
#
#                                        clean_article  \
# 0  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 1  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 2  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 3  [['Liputan6', '.', 'com', ',', 'Subang', ':', ...
# 4  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
#
#                                        clean_summary extractive_summary  \
# 0  [['Meski', 'belum', 'ada', 'hasil', 'resmi', '...             [4, 5]
# 1  [['Freddy', 'Santoso', ',', 'pelaku', 'penyuap...             [0, 2]
# 2  [['Fotografi', 'mode', 'terus', 'berkembang', ...          [0, 2, 4]
# 3  [['Seniman', 'Subang', 'menyerukan', 'memboiko...             [2, 6]
# 4  [['Suku', 'Dinas', 'Kependudukan', 'DKI', 'Jak...          [1, 9, 3]
#
#                               combined_clean_article  \
# 0  Liputan6. com, Jakarta: Hingga kini kerusakan ...
# 1  Liputan6. com, Jakarta: Freddy Santoso, pelaku...
# 2  Liputan6. com, Jakarta: Fotografi mode kini se...
# 3  Liputan6. com, Subang: Pro kontra tari jaipong...
# 4  Liputan6. com, Jakarta: Pemda Jakarta menggela...
#
#                               combined_clean_summary
# 0  Meski belum ada hasil resmi analisa penyebab k...
# 1  Freddy Santoso, pelaku penyuapan terhadap Iraw...
# 2  Fotografi mode terus berkembang dengan lebih m...
# 3  Seniman Subang menyerukan memboikot PKS dan me...
# 4  Suku Dinas Kependudukan DKI Jakarta menggelar ...

# %% [markdown]
# ### For Test and Validation file, datasets must be 2k only

# %% [markdown]
# #### Data_dev

# %%
def random_sampling_from_files(directory, sample_size):
    sampled_data2 = []
    all_files = [f for f in os.listdir(directory) if f.endswith('.json')]
    total_files = len(all_files)
    
    if sample_size > total_files:
        print(f"Warning: Sample size ({sample_size}) is larger than the number of files ({total_files}). Using all files.")
        files_to_sample = all_files
    else:
        files_to_sample = random.sample(all_files, sample_size)
    
    for file_name in tqdm(files_to_sample, desc="Sampling files"):
        file_path = os.path.join(directory, file_name)
        
        try:
            data = load_json(file_path)
            if isinstance(data, list) and len(data) > 0:
                sampled_data2.append(random.choice(data))
            elif isinstance(data, dict):
                sampled_data2.append(data)
        except FileNotFoundError:
            print(f"File {file_name} not found. Skipping.")
        except json.JSONDecodeError:
            print(f"Error decoding {file_name}. Skipping.")
        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}. Skipping.")
    
    return sampled_data2

def main():
    directory = r'F:\\AI Portfolio Project\\Project 2\\liputan6_data\\canonical\\dev'  # Directory file train (wajib double string biar ga error)
    sample_size = 2000 #fixed 2k only

    global sampled_data2
    sampled_data2 = random_sampling_from_files(directory, sample_size)
    
    print(f"Random sampling complete.")

if __name__ == "__main__":
    main()
# Out:
# Sampling files:   0%|          | 0/2000 [00:00<?, ?it/s]
# Sampling files: 100%|██████████| 2000/2000 [00:25<00:00, 77.34it/s]
# Random sampling complete.

# %%
sampled_data_dev = sampled_data2
sampled_data_dev[0]
# Out:
# {'id': 11043,
#  'url': 'https://www.liputan6.com/news/read/11043/tiga-perampok-mobil-beraksi-di-tebet',
#  'clean_article': [['Liputan6',
#    '.',
#    'com',
#    ',',
#    'Jakarta',
#    ':',
#    'Tiga',
#    'perampok',
#    'mobil',
#    'bersenjata',
#    'api',
#    'beraksi',
#    'di',
#    'rumah',
#    'keluarga',
#    'David',
#    'di',
#    'Jalan',
#    'Tebet',
#    'Barat',
#    'VII',
#    'No',
#    '.'],
#   ['8',
#    'A',
#    ',',
#    'Jakarta',
#    'Selatan',
#    ',',
#    'Selasa',
#    '(',
#    '10/4',
#    ')',
#    'pagi',
#    '.'],
#   ['Mereka',
#    'merampas',
#    'sebuah',
#    'mobil',
#    'jenis',
#    'Mitsubishi',
#    'Lancer',
#    'tahun',
#    '1993',
#    'setelah',
#    'melepaskan',
#    'dua',
#    'kali',
#    'tembakan',
#    'yang',
#    'kemudian',
#    'mengenai',
#    'tembok',
#    '.'],
#   ['Menurut',
#    'Nyonya',
#    'Linda',
#    'David',
#    ',',
#    'insiden',
#    'itu',
#    'berawal',
#    'pada',
#    'pukul',
#    '06',
#    '.',
#    '15',
#    'WIB',
#    '.'],
#   ['Saat',
#    'itu',
#    ',',
#    'suaminya',
#    'sedang',
#    'mengelap',
#    'mobil',
#    'di',
#    'halaman',
#    'rumah',
#    'mereka',
#    '.'],
#   ['Mendadak',
#    ',',
#    'tiga',
#    'pria',
#    'berusia',
#    '20-an',
#    'muncul',
#    'dan',
#    'berusaha',
#    'merampas',
#    'mobil',
#    'tersebut',
#    '.'],
#   ['Linda',
#    'mengatakan',
#    ',',
#    'suaminya',
#    'David',
#    'kontan',
#    'melakukan',
#    'perlawanan',
#    '.'],
#   ['Hal',
#    'itulah',
#    'yang',
#    'menyebabkan',
#    'seorang',
#    'perampok',
#    'melepaskan',
#    'tembakan',
#    '.'],
#   ['Letusan',
#    'tembakan',
#    'tadi',
#    'mengagetkan',
#    'keluarga',
#    'David',
#    'yang',
#    'lain',
#    'sehingga',
#    'mereka',
#    'menghambur',
#    'ke',
#    'luar',
#    '.'],
#   ['Namun',
#    ',',
#    'perampok',
#    'tadi',
#    'kembali',
#    'melepaskan',
#    'tembakan',
#    'ke',
#    'arah',
#    'mereka',
#    '.'],
#   ['Untungnya', ',', 'tembakan', 'itu', 'meleset', '.'],
#   ['Kendati',
#    'begitu',
#    ',',
#    'para',
#    'perampok',
#    'berhasil',
#    'melarikan',
#    'mobil',
#    'berwarna',
#    'abu-abu',
#    'bernomor',
#    'seri',
#    'B',
#    '1721',
#    'BV',
#    'tersebut',
#    '.'],
#   ['Sayangnya',
#    ',',
#    'petugas',
#    'Kepolisian',
#    'Sektor',
#    'Tebet',
#    ',',
#    'Jaksel',
#    ',',
#    'baru',
#    'datang',
#    'ke',
#    'lokasi',
#    'kejadian',
#    'beberapa',
#    'saat',
#    'kemudian',
#    '.'],
#   ['Para',
#    'polisi',
#    'hanya',
#    'mendapati',
#    'satu',
#    'proyektil',
#    'peluru',
#    'dan',
#    'selongsong',
#    'peluru',
#    'kaliber',
#    '32',
#    'serta',
#    'lubang',
#    'bekas',
#    'peluru',
#    'di',
#    'tembok',
#    'rumah',
#    '.'],
#   ['Sementara', ',', 'para', 'perampok', 'tersebut', 'lolos', '.'],
#   ['Hingga',
#    'saat',
#    'ini',
#    ',',
#    'polisi',
#    'masih',
#    'terus',
#    'melakukan',
#    'penyidikan',
#    'atas',
#    'kejahatan',
#    'mereka',
#    '.',
#    '(',
#    'ANS/Roy',
#    'Akhmad',
#    'dan',
#    'Agung',
#    'Nugroho',
#    ')',
#    '.']],
#  'clean_summary': [['Tiga',
#    'pria',
#    'perampok',
#    'bersenjata',
#    'api',
#    'berhasil',
#    'melarikan',
#    'mobil',
#    'sedan',
#    'dari',
#    'kawasan',
#    'Tebet',
#    ',',
#    'Jaksel',
#    ',',
#    'Selasa',
#    'pagi',
#    '.'],
#   ['Perampok',
#    'itu',
#    'sempat',
#    'melepaskan',
#    'dua',
#    'kali',
#    'tembakan',
#    ',',
#    'namun',
#    'meleset',
#    '.']],
#  'extractive_summary': [0, 10, 9]}

# %%
#combining into "combined_clean_article" and "combined_clean_summary"
data_dev = pd.json_normalize(sampled_data_dev)

def normalize_text(tokenized_text):
    normalized_text = ""
    for sentence in tokenized_text:
        for word in sentence:
            if word in [".", ",", ":", ";", "!", "?", ")", "]"]:
                normalized_text = normalized_text.rstrip() + word + " "
            elif word in ["(", "["]:
                normalized_text += word
            else:
                normalized_text += word + " "
    return normalized_text.strip()


data_dev['combined_clean_article'] = data_dev['clean_article'].apply(normalize_text)
data_dev['combined_clean_summary'] = data_dev['clean_summary'].apply(normalize_text)

# %%
#save CSV
output_file = 'F:\\AI Portfolio Project\\Project 2-new\\datasets\\data_dev.csv' # Directory untuk output (wajib double string biar ga error)
data_dev.to_csv(output_file, index=False)
print(f"total {len(data_dev)} items saved to {output_file}")
# Out:
# total 2000 items saved to F:\AI Portfolio Project\Project 2-new\datasets\data_dev.csv

# %% [markdown]
# #### Data_test

# %%
def random_sampling_from_files(directory, sample_size):
    sampled_data3 = []
    all_files = [f for f in os.listdir(directory) if f.endswith('.json')]
    total_files = len(all_files)
    
    if sample_size > total_files:
        print(f"Warning: Sample size ({sample_size}) is larger than the number of files ({total_files}). Using all files.")
        files_to_sample = all_files
    else:
        files_to_sample = random.sample(all_files, sample_size)
    
    for file_name in tqdm(files_to_sample, desc="Sampling files"):
        file_path = os.path.join(directory, file_name)
        
        try:
            data = load_json(file_path)
            if isinstance(data, list) and len(data) > 0:
                sampled_data3.append(random.choice(data))
            elif isinstance(data, dict):
                sampled_data3.append(data)
        except FileNotFoundError:
            print(f"File {file_name} not found. Skipping.")
        except json.JSONDecodeError:
            print(f"Error decoding {file_name}. Skipping.")
        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}. Skipping.")
    
    return sampled_data3

def main():
    directory = r'F:\\AI Portfolio Project\\Project 2\\liputan6_data\\canonical\\test'  # Directory file train (wajib double string biar ga error)
    sample_size = 2000 #fixed 2k only

    global sampled_data3
    sampled_data3 = random_sampling_from_files(directory, sample_size)
    
    print(f"Random sampling complete.")

if __name__ == "__main__":
    main()
# Out:
# Sampling files: 100%|██████████| 2000/2000 [00:29<00:00, 67.47it/s]
# Random sampling complete.

# %%
sampled_data_test = sampled_data3
sampled_data_test[0]
# Out:
# {'id': 17009,
#  'url': 'https://www.liputan6.com/news/read/17009/selangkah-lagi-mega--menjadi-presiden',
#  'clean_article': [['Liputan6',
#    '.',
#    'com',
#    ',',
#    'Jakarta',
#    ':',
#    'Wakil',
#    'Presiden',
#    'Megawati',
#    'Sukarnoputri',
#    'selangkah',
#    'lagi',
#    'naik',
#    'satu',
#    'tingkat',
#    'menjadi',
#    'presiden',
#    '.'],
#   ['Bahkan',
#    'boleh',
#    'dikatakan',
#    'Mega',
#    'tinggal',
#    'menunggu',
#    'pelantikan',
#    'saja',
#    '.'],
#   ['Demikian',
#    'laporan',
#    'reporter',
#    'SCTV',
#    'dari',
#    'Gedung',
#    'DPR/MPR',
#    ',',
#    'Senin',
#    '(',
#    '23/7',
#    ')',
#    '.'],
#   ['Selain',
#    'itu',
#    'dilaporkan',
#    ',',
#    'MPR',
#    'juga',
#    'sudah',
#    'menyiapkan',
#    'ketetapan',
#    'yang',
#    'akan',
#    'memberhentikan',
#    'Presiden',
#    'Abdurrahman',
#    'Wahid',
#    'dan',
#    'sekaligus',
#    'mengangkat',
#    'Megawati',
#    'sebagai',
#    'presiden',
#    '.'],
#   ['Sedangkan',
#    'mengenai',
#    'pemilihan',
#    'wakil',
#    'presiden',
#    ',',
#    'sampai',
#    'berita',
#    'ini',
#    'diturunkan',
#    'masih',
#    'menjadi',
#    'pembicaraan',
#    'untuk',
#    'diputuskan',
#    'pada',
#    'hari',
#    'ini',
#    'juga',
#    'atau',
#    'menyusul',
#    'pada',
#    'waktu',
#    'yang',
#    'akan',
#    'diputuskan',
#    'kemudian',
#    '.'],
#   ['Ada',
#    'kekhawatiran',
#    'bila',
#    'wapres',
#    'diputuskan',
#    'pada',
#    'hari',
#    'ini',
#    'juga',
#    ',',
#    'prosesnya',
#    'terlalu',
#    'cepat',
#    'sehingga',
#    'melahirkan',
#    'penilaian',
#    'bahwa',
#    'SI',
#    'menjadi',
#    'ajang',
#    'bagi-bagi',
#    'kekuasaan',
#    '.',
#    '(',
#    'YYT/Tim',
#    'Liputan',
#    '6',
#    'SCTV',
#    ')',
#    '.']],
#  'clean_summary': [['Megawati',
#    'Sukarnoputri',
#    'pasti',
#    'akan',
#    'menjadi',
#    'presiden',
#    '.'],
#   ['MPR',
#    'telah',
#    'mempersiapkan',
#    'ketetapan',
#    'untuk',
#    'memberhentikan',
#    'Presiden',
#    'Wahid',
#    'dan',
#    'mengangkat',
#    'Megawati',
#    '.']],
#  'extractive_summary': [0, 3]}

# %%
#combining into "combined_clean_article" and "combined_clean_summary"
data_test = pd.json_normalize(sampled_data_test)

def normalize_text(tokenized_text):
    normalized_text = ""
    for sentence in tokenized_text:
        for word in sentence:
            if word in [".", ",", ":", ";", "!", "?", ")", "]"]:
                normalized_text = normalized_text.rstrip() + word + " "
            elif word in ["(", "["]:
                normalized_text += word
            else:
                normalized_text += word + " "
    return normalized_text.strip()


data_test['combined_clean_article'] = data_test['clean_article'].apply(normalize_text)
data_test['combined_clean_summary'] = data_test['clean_summary'].apply(normalize_text)

# %%
#save CSV
output_file = 'F:\\AI Portfolio Project\\Project 2-new\\datasets\\data_test.csv' # Directory untuk output (wajib double string biar ga error)
data_test.to_csv(output_file, index=False)
print(f"total {len(data_test)} items saved to {output_file}")
# Out:
# total 2000 items saved to F:\AI Portfolio Project\Project 2-new\datasets\data_test.csv

# %% [markdown]
# ### Last Check for CSV Files

# %%
#checking total datasets
check_train = pd.read_csv('F:\AI Portfolio Project\Project 2-new\datasets\data_train.csv')
check_test = pd.read_csv('F:\AI Portfolio Project\Project 2-new\datasets\data_test.csv')
check_dev = pd.read_csv('F:\AI Portfolio Project\Project 2-new\datasets\data_dev.csv')
check_train.shape, check_test.shape, check_dev.shape
# Out:
# ((10000, 7), (2000, 7), (2000, 7))

# %%
#checking example data table
check_train.head()
# Out:
#        id                                                url  \
# 0  288252  https://www.liputan6.com/news/read/288252/peme...
# 1  148249  https://www.liputan6.com/news/read/148249/fred...
# 2   30242  https://www.liputan6.com/news/read/30242/perke...
# 3  198447  https://www.liputan6.com/news/read/198447/pks-...
# 4   27679  https://www.liputan6.com/news/read/27679/pemda...
#
#                                        clean_article  \
# 0  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 1  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 2  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 3  [['Liputan6', '.', 'com', ',', 'Subang', ':', ...
# 4  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
#
#                                        clean_summary extractive_summary  \
# 0  [['Meski', 'belum', 'ada', 'hasil', 'resmi', '...             [4, 5]
# 1  [['Freddy', 'Santoso', ',', 'pelaku', 'penyuap...             [0, 2]
# 2  [['Fotografi', 'mode', 'terus', 'berkembang', ...          [0, 2, 4]
# 3  [['Seniman', 'Subang', 'menyerukan', 'memboiko...             [2, 6]
# 4  [['Suku', 'Dinas', 'Kependudukan', 'DKI', 'Jak...          [1, 9, 3]
#
#                               combined_clean_article  \
# 0  Liputan6. com, Jakarta: Hingga kini kerusakan ...
# 1  Liputan6. com, Jakarta: Freddy Santoso, pelaku...
# 2  Liputan6. com, Jakarta: Fotografi mode kini se...
# 3  Liputan6. com, Subang: Pro kontra tari jaipong...
# 4  Liputan6. com, Jakarta: Pemda Jakarta menggela...
#
#                               combined_clean_summary
# 0  Meski belum ada hasil resmi analisa penyebab k...
# 1  Freddy Santoso, pelaku penyuapan terhadap Iraw...
# 2  Fotografi mode terus berkembang dengan lebih m...
# 3  Seniman Subang menyerukan memboikot PKS dan me...
# 4  Suku Dinas Kependudukan DKI Jakarta menggelar ...

# %%
check_test.head()
# Out:
#       id                                                url  \
# 0  17009  https://www.liputan6.com/news/read/17009/selan...
# 1  25824  https://www.liputan6.com/news/read/25824/adnan...
# 2  17119  https://www.liputan6.com/news/read/17119/jalur...
# 3  14898  https://www.liputan6.com/news/read/14898/wapre...
# 4  25464  https://www.liputan6.com/news/read/25464/ribua...
#
#                                        clean_article  \
# 0  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 1  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 2  [['Liputan6', '.', 'com', ',', 'Semarang', ':'...
# 3  [['Liputan6', '.', 'com', ',', 'Bali', ':', 'W...
# 4  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
#
#                                        clean_summary extractive_summary  \
# 0  [['Megawati', 'Sukarnoputri', 'pasti', 'akan',...             [0, 3]
# 1  [['Pemerintah', 'harus', 'memberikan', 'alasan...            [0, 16]
# 2  [['Sehari', 'setelah', 'pelantikan', 'Megawati...             [0, 5]
# 3  [['Pesta', 'kesenian', 'Bali', 'ke-23', 'dibuk...             [0, 1]
# 4  [['Ribuan', 'pemudik', 'tujuan', 'ke', 'bebera...             [0, 1]
#
#                               combined_clean_article  \
# 0  Liputan6. com, Jakarta: Wakil Presiden Megawat...
# 1  Liputan6. com, Jakarta: Pemerintah sebaiknya m...
# 2  Liputan6. com, Semarang: Kepala Kepolisian Dae...
# 3  Liputan6. com, Bali: Wakil Presiden Megawati S...
# 4  Liputan6. com, Jakarta: Ribuan pemudik tujuan ...
#
#                               combined_clean_summary
# 0  Megawati Sukarnoputri pasti akan menjadi presi...
# 1  Pemerintah harus memberikan alasan hukum menga...
# 2  Sehari setelah pelantikan Megawati Sukarnoputr...
# 3  Pesta kesenian Bali ke-23 dibuka Wapres Megawa...
# 4  Ribuan pemudik tujuan ke beberapa kota di Pula...

# %%
check_dev.head()
# Out:
#       id                                                url  \
# 0  11043  https://www.liputan6.com/news/read/11043/tiga-...
# 1    623  https://www.liputan6.com/news/read/623/aparat-...
# 2   8843  https://www.liputan6.com/news/read/8843/pemeri...
# 3   9563  https://www.liputan6.com/news/read/9563/penduk...
# 4   3478  https://www.liputan6.com/news/read/3478/hari-i...
#
#                                        clean_article  \
# 0  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 1  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 2  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 3  [['Liputan6', '.', 'com', ',', 'Jakarta', ':',...
# 4  [['Liputan6', '.', 'com', ',', 'Banda', 'Aceh'...
#
#                                        clean_summary extractive_summary  \
# 0  [['Tiga', 'pria', 'perampok', 'bersenjata', 'a...         [0, 10, 9]
# 1  [['Aparat', 'keamanan', 'dianggap', 'bersalah'...             [0, 4]
# 2  [['Sebanyak', '40', 'persen', 'saham', 'pemeri...             [1, 5]
# 3  [['Ribuan', 'pendukung', 'Presiden', 'Wahid', ...             [1, 2]
# 4  [['Sidang', 'Rakyat', 'Aceh', 'yang', 'digelar...            [1, 10]
#
#                               combined_clean_article  \
# 0  Liputan6. com, Jakarta: Tiga perampok mobil be...
# 1  Liputan6. com, Jakarta: Aktivis mahasiswa yang...
# 2  Liputan6. com, Jakarta: Pemerintah dan Komisi ...
# 3  Liputan6. com, Jakarta: Sekitar enam ribu pend...
# 4  Liputan6. com, Banda Aceh: Meski ribuan massa ...
#
#                               combined_clean_summary
# 0  Tiga pria perampok bersenjata api berhasil mel...
# 1  Aparat keamanan dianggap bersalah terhadap jat...
# 2  Sebanyak 40 persen saham pemerintah di BCA aka...
# 3  Ribuan pendukung Presiden Wahid meninggalkan I...
# 4  Sidang Rakyat Aceh yang digelar selama dua har...
